# %%
# Q1. 소용돌이 수
# -*- coding: utf-8 -*-
# UTF-8 encoding when using korean
def solution(n):
    list = [[0]*n for _ in range(n)]
    x,y= 0,0
    route_axis = 0
    route = [[1, 0], [0,1],[-1,0], [0,-1]]
    for i in range(n**2):
        nx
        list[x+route[route_axis%4][0]][y+route[route_axis%4][1]] = i
        if (0<=x<n and 0<=y<n and list[x+(route[route_axis%4][0]*2)][y+(route[route_axis%4][1]*2)]!= 0):
            x+=1
            y+=1
        else:
            route_axis+1
    print(list)


n1=3
ret1 = solution(n1)
print(f"solution 함수의 반환 값은 {ret1}입니다")

n2=2
ret1 = solution(n2)
print(f"solution 함수의 반환 값은 {ret1}입니다")
# Out:
# [[0, 0, 0], [8, 0, 0], [0, 0, 0]]
# solution 함수의 반환 값은 None입니다
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[8], line 28
#      25 print(f"solution 함수의 반환 값은 {ret1}입니다")
#      27 n2=2
# ---> 28 ret1 = solution(n2)
#      29 print(f"solution 함수의 반환 값은 {ret1}입니다")
#
# Cell In[8], line 15, in solution(n)
#      13 for i in range(n**2):
#      14     list[x+route[route_axis%4][0]][y+route[route_axis%4][1]] = i
# ---> 15     if (0<=x<n and 0<=y<n and list[x+(route[route_axis%4][0]*2)][y+(route[route_axis%4][1]*2)]!= 0):
#      16         x+=1
#      17         y+=1
#
# IndexError: list index out of range

# %%
# Q2.
# -*- coding: utf-8 -*-
# UTF-8 encoding when using korean

# %%
# Q3.
# -*- coding: utf-8 -*-
# UTF-8 encoding when using korean

# %%
# Q4.
# -*- coding: utf-8 -*-
# UTF-8 encoding when using korean

# %%
# Q5.
# -*- coding: utf-8 -*-
# UTF-8 encoding when using korean

# %%
# Q6.
# -*- coding: utf-8 -*-
# UTF-8 encoding when using korean

# %%
# Q7.
# -*- coding: utf-8 -*-
# UTF-8 encoding when using korean

# %%
# Q8.
# -*- coding: utf-8 -*-
# UTF-8 encoding when using korean

# %%
# Q9.
# -*- coding: utf-8 -*-
# UTF-8 encoding when using korean

# %%
# Q10.
# -*- coding: utf-8 -*-
# UTF-8 encoding when using korean
