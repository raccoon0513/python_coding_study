# %%
# Q1. 직각 만들기 1
# -*- coding: utf-8 -*-
# UTF-8 encoding when using korean
N = int(input())
for i in range(N):

# %%
# Q2.
# -*- coding: utf-8 -*-
# UTF-8 encoding when using korean

# %%
# Q3.
# -*- coding: utf-8 -*-
# UTF-8 encoding when using korean

# %%
# Q4.
# -*- coding: utf-8 -*-
# UTF-8 encoding when using korean

# %%
# Q5.
# -*- coding: utf-8 -*-
# UTF-8 encoding when using korean

# %%
# Q6.
# -*- coding: utf-8 -*-
# UTF-8 encoding when using korean

# %%
# Q7.
# -*- coding: utf-8 -*-
# UTF-8 encoding when using korean

# %%
# Q8.
# -*- coding: utf-8 -*-
# UTF-8 encoding when using korean

# %%
# Q9.
# -*- coding: utf-8 -*-
# UTF-8 encoding when using korean

# %%
# Q10.
# -*- coding: utf-8 -*-
# UTF-8 encoding when using korean
