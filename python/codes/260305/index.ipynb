# %%
import math
pi = math.pi
print("원주율은", pi, "입니다")
print("원주율은 {} 입니다.". format(pi))
print(f"원주율은 {pi} 입니다.")
# Out:
# 원주율은 3.141592653589793 입니다
# 원주율은 3.141592653589793 입니다.
# 원주율은 3.141592653589793입니다

# %%
#외부입력
pi = float(input())
print(pi)
# Out:
# 3.14

# %%
print(f"원주율은 {pi} 입니다.")
print(type(pi))
# Out:
# 원주율은 3.141592653589793438 입니다.
# <class 'str'>

# %%
## 타입 변환
pi2 = float(input())

# %%
pi = 3.14
print(int(pi))
# Out:
# 3
